# %% [markdown]
# ## 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# <br>[Histopathologic Cancer Detection](https://www.kaggle.com/c/histopathologic-cancer-detection)
# 1. 你選的這組資料為何重要
# <br>可用於切片的判讀，提昇正確性。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# <br>資料取自[PatchCamelyon（PCam）](https://github.com/basveeling/pcam)從中移除了重複的項目。PCam由[Bas Veeling](https://github.com/basveeling)提供。依據github上的說明資料來自於學術論文 [1] B. S. Veeling, J. Linmans, J. Winkens, T. Cohen, M. Welling. Rotation Equivariant CNNs for Digital Pathology. arXiv:1806.03962 [2] Ehteshami Bejnordi et al. Diagnostic Assessment of Deep Learning Algorithms for Detection of Lymph Node Metastases in Women With Breast Cancer. JAMA: The Journal of the American Medical Association, 318(22), 2199–2210. doi:jama.2017.14585，實際的取得方式應來自臨床研究。
# 3. 蒐集而來的資料型態為何
# <br>96*96px彩色圖檔
# 4. 這組資料想解決的問題如何評估
# <br>Submissions are evaluated on area under the **ROC** curve between the predicted probability and the observed target.

# %% [markdown]
# ## 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# <br>調派車隊在適當的時間位於多個叫車的熱點附近，便能「增加派車的密度」，「減少司機空車等待的時間」，以提昇業績。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# <br>資料來自派車的歷史紀錄，其中包含時間（年月日時分、星期幾）、出發地點、目的地、旅程時間、當地的天氣（用氣象資料庫匹配），可用於分析以找出產生熱點的模型。
# 3. 蒐集而來的資料型態為何
# <br>資料型態為結構化的文字型態
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# <br>每個月載客量以MSE驗證其變化。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import math as pow
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    mse = sum((y - y_hat)**2) / len (y)
    return mse

# %%
def mean_absolute_error(y, y_hat):
    mae = MAE = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'xxxxx')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 220.604
# The Mean absolute error is 12.470
